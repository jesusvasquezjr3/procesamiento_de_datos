# %% [markdown]
# # Escalado
# Conjunto de datos: iris (incluido en sklearn)
# Este conjunto de datos es compacto y perfecto para demostrar técnicas de escalado.

# %%
# Importar librerías necesarias
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos
iris = load_iris(as_frame=True)
data = iris.data

# %%
# Visualizar las estadísticas iniciales
print("Estadísticas iniciales:")
data.describe()
# Out:
# Estadísticas iniciales:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Aplicar MinMaxScaler
minmax_scaler = MinMaxScaler()
data_minmax = pd.DataFrame(minmax_scaler.fit_transform(data), columns=data.columns)

# %%
# Aplicar StandardScaler
standard_scaler = StandardScaler()
data_standard = pd.DataFrame(standard_scaler.fit_transform(data), columns=data.columns)

# %% [markdown]
# # Ejercicios
# Contesta las siguientes preguntas. Para cada pregunta, deberás escribir código que demostrará cómo llegaste al resultado. Crea gráficas en donde veas correcto.

# %% [markdown]
# # 1. Comparación de estadísticas
# print("Estadísticas Originales:")
# print(data.describe())
# print("\nEstadísticas MinMax (0 a 1):")
# print(data_minmax.describe())
# # Nota: Tras el escalado MinMax, el mínimo es 0 y el máximo es 1 para todas las columnas.

# %% [markdown]
# # 2. Distribución de 'sepal length (cm)'
# import seaborn as sns
# plt.figure(figsize=(12, 5))
#
# plt.subplot(1, 2, 1)
# sns.histplot(data['sepal length (cm)'], kde=True, color='blue')
# plt.title('Original')
#
# plt.subplot(1, 2, 2)
# sns.histplot(data_minmax['sepal length (cm)'], kde=True, color='red')
# plt.title('MinMax Scaled')
#
# plt.show()

# %% [markdown]
# # 3. Dispersión con StandardScaler
# plt.figure(figsize=(8, 6))
# plt.scatter(data_standard['sepal length (cm)'], data_standard['sepal width (cm)'], alpha=0.7)
# plt.title('Sepal Length vs Width (StandardScaler)')
# plt.xlabel('Sepal Length (Scaled)')
# plt.ylabel('Sepal Width (Scaled)')
# plt.grid(True)
# plt.show()

# %% [markdown]
# # 4. Recomendación técnica
# # Para el dataset Iris, StandardScaler suele ser preferible si se asume una distribución normal
# # y se desean centrar los datos en 0 con varianza 1. MinMaxScaler es útil si se requiere
# # un rango específico [0,1] para algoritmos como redes neuronales o KNN.
